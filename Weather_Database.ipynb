# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# -70.40033692084533 16.07757761123429
# 36.06397469245887 154.04478582457187
# -34.15971440159946 144.18767378340561
# -76.25205230404953 76.61670016060441
# 19.033277490100943 55.04940191082875
# 15.422817802146596 -60.49940472229673
# -83.59983793122873 -119.8027490361431
# -83.23017424178022 -140.78328384172596
# 55.870366374631914 -129.26731113967378
# -22.568511292324132 -94.07526709072046
# 24.98189155498588 113.0140352178069
# -69.62790346325201 79.63514997826707
# 7.412091823718711 58.73105858411458
# 85.64085438177412 -54.61305475496239
# 39.07404888416275 1.8970403009878112
# 87.8802542227339 -41.17285310933539
# 71.21572274417224 -104.621722548525
# 62.201928502133995 -51.9012869566038
# -42.03904102667808 104.83838143416585
# 36.271195676684684 125.72542582734343
# 31.444032978643733 144.30493699179402
# 28.795545666970128 28.866752674793815
# -51.65650434088715 94.60201568756912
# 29.160875584234702 -101.59034827326485
# -33.793121042159434 -163.3906601803023
# ...

# %%
#6.1.5
cities = []
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=52791796aff356fe464a35f80654d5ff

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Loop through all the cities in our list.
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass 

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | swan hill
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | salalah
# Processing Record 6 of Set 1 | la plaine
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | terrace
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | shaoguan
# Processing Record 12 of Set 1 | bandarbeyla
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | nuuk
# Processing Record 18 of Set 1 | seoul
# Processing Record 19 of Set 1 | katsuura
# Processing Record 20 of Set 1 | matay
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp -34.5322   20.0403     50.52        91           0
# 1     Swan Hill -35.3378  143.5544     48.49        84          98
# 2     Busselton -33.6500  115.3333     51.55        74           5
# 3       Salalah  17.0151   54.0924     77.09        94         100
# 4     La Plaine  15.3333  -61.2500     88.09        55          20
# 5  Punta Arenas -53.1500  -70.9167     42.12        70          20
# 6       Rikitea -23.1203 -134.9692     74.03        72         100
# 7       Terrace  54.5163 -128.6035     87.22        45           3
# 8         Pisco -13.7000  -76.2167     64.45        77          20
# 9      Shaoguan  24.8000  113.5833     79.84        80          58
#
#    Wind Speed Country                 Date
# 0        5.79      ZA  2022-07-27 20:10:48
# 1        9.04      AU  2022-07-27 20:10:48
# 2        7.14      AU  2022-07-27 20:10:49
# 3        6.91      OM  2022-07-27 20:10:49
# ...

# %%
#del city_data_df['Date']
city_data_df['Weather Score'] = city_data_df['Humidity'] + city_data_df['Cloudiness'] + city_data_df['Max Temp']
bins = [70, 155, 198, 235, 273]
group_names = ["Clear Skies and Light", "Slightly cloudy and Cool", "Cool and Cloudy", "Warm and Humid"]
city_data_df["Weather Description"] = pd.cut(city_data_df["Weather Score"], bins, labels=group_names)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp -34.5322   20.0403     50.52        91           0
# 1     Swan Hill -35.3378  143.5544     48.49        84          98
# 2     Busselton -33.6500  115.3333     51.55        74           5
# 3       Salalah  17.0151   54.0924     77.09        94         100
# 4     La Plaine  15.3333  -61.2500     88.09        55          20
# ..          ...      ...       ...       ...       ...         ...
# 675    Hamilton  39.1834  -84.5333     83.59        79         100
# 676      Nicoya  10.1483  -85.4520     83.05        72          64
# 677      Kaseda  31.4167  130.3167     79.74        88          41
# 678     Tucuman -26.8241  -65.2226     78.80        50          75
# 679      Sayyan  15.1718   44.3244     64.11        66         100
#
#      Wind Speed Country  Weather Score       Weather Description
# 0          5.79      ZA         141.52     Clear Skies and Light
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
